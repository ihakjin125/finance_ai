# %%
import pandas as pd

from src.news import get_news
from src.config import NEWS_QUERIES

all_news = []

for query in NEWS_QUERIES.values():
    all_news.extend(get_news(query))

news_df = pd.DataFrame(all_news)

news_df.head()
# Out:
#      종목                                         제목  \
# 0  삼성전자  코스피 7284.41 마감…하루 만에 '7천피' 탈환한 숨은 공신, 무엇?
# 1  삼성전자  추미애 "삼성 반도체 인허가 하루라도 앞당겨라"…반도체 초격차 전략 ...
# 2  삼성전자        “늘린 캐파, 인력 못 따라가”…치열해진 반도체 ‘인재 쟁탈전’
# 3  삼성전자                코스피, 6%대 급반등⋯3거래일 만에 7천피 탈환
# 4  삼성전자   SK하이닉스, 황제주 시동...최태원 회장 '액면분할' 카드, 실효성은?
#
#                                                   링크  \
# 0        https://www.wikitree.co.kr/articles/1146653
# 1  http://www.econonews.co.kr/news/articleView.ht...
# 2  http://www.newstomato.com/ReadNews.aspx?no=130...
# 3         https://www.etoday.co.kr/news/view/2604125
# 4  https://www.insightkorea.co.kr/news/articleVie...
#
#                                                   요약  \
# 0  대장주 삼성전자는 전 거래일 대비 1만 6500원 상승한 27만 9500원으로 마감...
# 1  (사진=경기도) 추미애 경기도지사가 삼성전자 평택캠퍼스 증설과 용인 반도체 국가산업...
# 2  뉴스토마토 = 이명신 기자 |  고대역폭메모리(HBM) 등 인공지능(AI) 반도체 ...
# 3  이투데이=김범근 기자 | 코스피, 7284 마감, 장 초반 양 시장서 사이드카 삼성...
# 4  익명을 요구한 한 증권업계 관계자는 "본주 가격이 100만원을 넘는 이른바 황제주가...
#
#                                 날짜
# 0  Wed, 15 Jul 2026 15:46:00 +0900
# 1  Wed, 15 Jul 2026 15:46:00 +0900
# 2  Wed, 15 Jul 2026 15:46:00 +0900
# 3  Wed, 15 Jul 2026 15:46:00 +0900
# 4  Wed, 15 Jul 2026 15:46:00 +0900
